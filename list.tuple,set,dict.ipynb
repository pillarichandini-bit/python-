# %%
#tuples in python
#tuple is a collection of multiple values that is ordered and cannot be chnaged after creation
student =("chandini",98,"python")

print(student[0])
# Out:
# chandini

# %%
print(student.keys())

#  keys() returns all the keys in the dictionary 

print(student.values())
# values() returns all the values in the dictionary 

print(student.item())
# items() returns all key-value pairs 

print(student.get("name"))
# get() returns the values of the specified key


student.update({"age": 22})

#update() updates the value of the specified key 

print(student)

student.pop("age")

#pop() removes the specified key and its values

print(student)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 print(student.keys())
#       2
#       3 #  keys() returns all the keys in the dictionary
#       4
#
# NameError: name 'student' is not defined

# %%
numbers = (10, 20, 30, 40)

print(len(numbers))
print(max(numbers))
print(min(numbers))
print(sum(numbers))
# Out:
# 4
# 40
# 10
# 100

# %%
#sets in python 
#set is a collection of unique values that is unordered and mutable 

numbers = {10, 20, 30, 20, 10}

print(numbers)
# Out:
# {10, 20, 30}

# %%
#add values to a set 

subjects = {"python", "java"}

subjects.add("SQL")

print(subjects)
# Out:
# {'SQL', 'java', 'python'}

# %%
#remove values from a set 

subjects = {"java"}


subjects.remove("Java")

print(subjects)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[10], line 6
#       2
#       3 subjects = {"java"}
#       4
#       5
# ----> 6 subjects.remove("Java")
#       7
#       8 print(subjects)
#       9
#
# KeyError: 'Java'

# %%
#sets do not allow duplicate values 

numbers = {1, 2, 2, 3, 3, 4}

print(numbers)
# Out:
# {1, 2, 3, 4}

# %%
#add new data to a dictionary 

student["city"] = "Vijayawada"

print(student)
# Out:
# {'name': 'chandini', 'age': 18, 'course': 'python', 'city': 'Vijayawada'}

# %%
#dictionary in python 

#Dictionary is a collection of key-value pairs that is unorderes 

student = { 
    "name": "chandini",
    "age":  18,
    "course": "python" }


print(student)
# Out:
# {'name': 'chandini', 'age': 18, 'course': 'python'}

# %%
numbers = (10, 20, 30, 40)

print(numbers.index(30))
# Out:
# 2

# %%
#tuples are immutable, meaning they cannot be changed after they are created.

numbers = (10, 20, 20, 30, 20)

print(numbers.count(20))

# %%
#access elements in dic

print(student["name"])
print(student["age"])
print(student["course"])
# Out:
# chandini
# 18
# python

# %%
#popitem() removes the laast inserted key-value pair 

student = { 
    "name": "chandini",
    "age" : 18,
    "course" : "python"}

student.popitem()

print(student)
# Out:
# {'name': 'chandini', 'age': 18}

# %%
student = {
    "name" : "chandini"}

student.setdefault("age",18)

print(student)
# Out:
# {'name': 'chandini', 'age': 18}

# %%
#immutable nature of tuples
student = ("chandini",18,16.2 )

student[1] = 18 
#this gives an error because we cannot modify a tuple
